# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,16])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0,6,0,20])# x:0~6, y:0~10
plt.ylabel('some numbers')
plt.show()

# %%
t = np.arange(0, 5, 0.2)
plt.plot(t,t,'r--', t, t**2, 'bs', t, t**3, 'g^')
# Out:
# [<matplotlib.lines.Line2D at 0x7fdc040ceee0>,
#  <matplotlib.lines.Line2D at 0x7fdc040cedc0>,
#  <matplotlib.lines.Line2D at 0x7fdc040cefd0>]

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
area = np.random.rand(50)*100
plt.scatter(x,y,s=area, c=colors, alpha=0.5)
plt.show()

# %%
objects = ('a', 'b', 'c', 'd', 'e', 'f')
y_pos = np.arange(len(objects))

value=[1,2,3,4,5,6]

plt.bar(y_pos, value, alpha=0.5)
# Out:
# <BarContainer object of 6 artists>

# %%
labels = ['Python', 'C++', 'Ruby', 'Java']
sizes = [10,20,30,40]
colors=['red', 'yellow', 'green', 'blue']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True)
plt.axis('equal')
plt.show()

# %%
y = [2,4,6,8,10]
y2 = [10,11,12,13,14]
x = np.arange(5)

plt.plot(x,y,label='y')
plt.plot(x,y2,label='y2')
plt.legend()
plt.show()
